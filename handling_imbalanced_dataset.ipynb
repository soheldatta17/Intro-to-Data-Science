# %% [markdown]
# <a href="https://colab.research.google.com/github/soheldatta17/Intro-to-Data-Science/blob/main/handling_imbalanced_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Imbalanced Dataset:**
#
# A dataset with an unequal class distribution

# %%
# importing the dependencies
import numpy as np
import pandas as pd

# %%
# loading the dataset to pandas DataFrame
credit_card_data = pd.read_csv('/content/credit_data.csv')

# %%
# first 5 rows of the dataframe
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
credit_card_data.tail()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 1981  1524 -0.340622  1.132232  1.291494  0.062313  0.016387 -0.977070
# 1982  1525 -1.842696  1.740641  0.861526 -0.856315 -0.655376 -0.842786
# 1983  1525 -0.480693  0.646091  1.577264 -0.084411 -0.305958 -0.534739
# 1984  1525 -0.342132  1.091125  1.282729  0.068076 -0.022498 -0.996727
# 1985  1526 -0.854343  1.382948  1.278665  2.914727 -0.183139 -0.349329
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 1981  0.723755 -0.074630 -0.396655  ... -0.262948 -0.688785 -0.010937
# 1982  0.198563  0.602764  0.455595  ... -0.213609 -0.400617  0.030013
# 1983  0.860346 -0.028569 -0.800705  ...  0.121681  0.175190  0.035986
# 1984  0.676304 -0.042250 -0.312036  ... -0.269850 -0.734148 -0.007354
# 1985  0.274566  0.435277 -1.576521  ...       NaN       NaN       NaN
#
#            V24       V25       V26       V27       V28  Amount  Class
# 1981  0.334061 -0.160025  0.071779  0.245128  0.098336    5.35    0.0
# 1982  0.512611 -0.077087  0.286218  0.586012  0.352610    1.00    0.0
# 1983  0.557665 -0.112301  0.337154 -0.015602  0.051504   80.70    0.0
# 1984  0.319161 -0.179146  0.073683  0.241932  0.097139    3.59    0.0
# 1985       NaN       NaN       NaN       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
# distribution of the two classes
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    1983
# 1.0       2
# Name: count, dtype: int64

# %% [markdown]
# This is Highly Imbalanced Dataset

# %% [markdown]
# 0 --> Legit Transactions
#
# 1 --> Fraudulent Transactions

# %%
# separating the legit and fraudulent transactions
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (1983, 31)
# (2, 31)

# %% [markdown]
# Under-sampling

# %% [markdown]
# Build a sample dataset containing similar distribution of Legit & Fraudulent Transactionds

# %% [markdown]
# Number of Fraudulent Transactions --> 492

# %%
legit_sample = legit.sample(n=492)

# %%
print(legit_sample.shape)
# Out:
# (492, 31)

# %% [markdown]
# Concatenate the Two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis = 0)

# %%
new_dataset.head()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 1656  1283 -1.018954  0.151756  1.737273 -0.373036  0.802996 -0.743039
# 1378  1072 -0.501898  0.200435  1.217419 -0.181981 -0.420186  0.083728
# 4        2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# 50      35  1.199356  0.129953  0.863585  1.002635 -0.783761 -0.884679
# 389    284  1.141436  0.081893  0.503625  1.487212 -0.473170 -0.411384
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 1656  0.191905  0.231507 -0.617842  ... -0.014405 -0.341984  0.148907
# 1378  0.990755  0.063176 -0.254466  ... -0.053073 -0.319245  0.187640
# 4     0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458
# 50   -0.040743 -0.208069  0.392478  ... -0.042468  0.198474 -0.033010
# 389  -0.053193  0.071036  0.553486  ... -0.102341 -0.150234  0.001322
#
#            V24       V25       V26       V27       V28  Amount  Class
# 1656  0.186871 -0.505780 -0.085566  0.054083  0.129712    1.98    0.0
# 1378  0.030717  0.038197  0.460777 -0.072873  0.011141  158.00    0.0
# 4     0.141267 -0.206010  0.502292  0.219422  0.215153   69.99    0.0
# 50    1.013290  0.559098  0.401818 -0.005865  0.017936    0.99    0.0
# 389   0.369459  0.556295 -0.326645  0.028101  0.015215    7.89    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 1315  1030 -0.565615  0.983078  1.333589  0.007014 -0.102888 -0.836389
# 1007   759  1.130109 -0.204418  0.868317  1.531755 -0.318637  1.070985
# 627    478 -0.394364  0.962489  1.164111 -0.110028  0.221216 -0.526324
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 1315  0.483634  0.106021 -0.384015  ... -0.199176 -0.651842  0.060627
# 1007 -0.553303  0.342627  1.327647  ... -0.469380 -0.885483 -0.022070
# 627   0.505040  0.147743 -0.499457  ... -0.240069 -0.709400 -0.051337
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
#
#            V24       V25       V26       V27       V28  Amount  Class
# 1315  0.444598 -0.266541  0.035166  0.099430  0.086012    1.78    0.0
# 1007 -0.775433  0.531546 -0.457121  0.088653  0.020612   15.00    0.0
# 627  -0.071240 -0.173978  0.077661  0.234553  0.083875    1.79    0.0
# 541   0.320198  0.044519  0.177840  0.261145 -0.143276    0.00    1.0
# 623  -0.293803  0.279798 -0.145362 -0.252773  0.035764  529.00    1.0
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0      2
# Name: count, dtype: int64
